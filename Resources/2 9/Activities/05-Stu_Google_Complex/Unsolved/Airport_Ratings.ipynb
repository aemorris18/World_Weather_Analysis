# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import gmaps

# Import API key
from config import gkey

# %%
# Import cities file into the cities_pd DataFrame
cities_df = pd.DataFrame()

# %%
# Add columns for lat, lng, airport name, airport address, airport rating.
cities_df = pd.read_csv("../Resources/cities.csv")
cities_df.head()
# Hint: Be sure to specify "" as the initial value for each column.
cities_df['Lat'] = ""
cities_df['Lng'] = ""
cities_df['Aiport Name'] = ""
cities_df['Aiport Address'] = ""
cities_df['Aiport Rating'] = ""
cities_df.head()
# Out:
#             City         State Lat Lng Aiport Name Aiport Address  \
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania
#
#   Aiport Rating
# 0
# 1
# 2
# 3
# 4

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "lat":
    "lng":
    "address"
    
    "rankby": "distance",
    "type": "aiports",
    "key": gkey,
}

# %%
# Loop through the cities_pd and get the lat/long for each city
# Hint: `requests.get(target_url).json()`
# Hint: `for index, row in cities_pd.iterrows():`
# Hint: `cities_pd.loc`
for index, row in cities_df.iterrows():

    # get aiports type from df
    city_name = row['City']

    # add keyword to params dict
    params['address'] = city_name

    # assemble url and make API request
    #print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()

    # extract results
    results = response['results']
    
    print(response)
    
   # try:
       # print(f"Closest {city_name} aiport is {results[0]['name']}.")
        
       # cities_df.loc[index, 'name'] = results[0]['name']
       # cities_df.loc[index, 'address'] = results[0]['vicinity']
       # cities_df.loc[index, 'price_level'] = results[0]['price_level']
       # cities_df.loc[index, 'rating'] = results[0]['rating']
        
   # except (KeyError, IndexError):
       # print("Missing field/result... skipping.")
        
   # print("------------")
# Out:
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}

# %%
# Use the lat/lng we recovered to identify airports
# Hint: Code is similar to above block (i.e. you will need to use cities_pd.iterrows() again)
# Hint: Use the keyword search for "international+airport"
# Hint: Use a try-except to handle airports that are missing ratings

# %%
# Save Data to csv


# Visualize to confirm airport data appears
